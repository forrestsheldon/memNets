# %% [markdown]
# # Varying the Memory

# %%
# %matplotlib inline

# %%
import numpy as np
import scipy as sp
import scipy.sparse as sparse
import matplotlib.pyplot as plt
import generate_adjacency_matrix as gen_adj
import resistor_networks as rnets
from __future__ import division

# %% [markdown]
# We consider switching between two values of the resistance, $R$ and $(1-\delta)R$. We would like to see what result varying $\delta$ has on the switching time distribution.  As $\delta\to 0$ we get the non-interacting/no-memory picture we have considered thusfar. The $\delta=0$ case is simple in that we do not need to update our resistances at each switching and thus the switching times may be calculated from the initial voltage distribution.  In the case of nonzero $\delta$ we will need to work a bit harder.

# %% [markdown]
# ## $\delta=0$

# %%
# Initialize a network
L = 512
p = 0.6
random_lattice = gen_adj.cubic_2d_random((L,L), p)
v_external = np.empty(L*L) * np.nan
v_external[0:L] = 1
v_external[-L:] = 0
rnet = rnets.ResistorNetworkCC(random_lattice, v_external)

#Solve for the voltages
rnet.solve_voltages('spsolve')
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/lib/nanfunctions.py:319: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)
# /usr/local/lib/python2.7/dist-packages/numpy/lib/nanfunctions.py:220: RuntimeWarning: All-NaN axis encountered
#   warnings.warn("All-NaN axis encountered", RuntimeWarning)

# %%
def calculate_voltage_drops(G, voltages):
    rows, cols = G.nonzero()
    drops_list = []
    for i, j in zip(rows, cols):
        if i < j:
            drop = np.abs(voltages[i] - voltages[j])
            if drop > 1e-12:
                drops_list.append(drop)
    return drops_list

#get the voltage drops across this network and take a look
voltage_drops = calculate_voltage_drops(rnet.G, rnet.voltages)
hist, bins = np.histogram(np.log10(voltage_drops), 150)

fig, ax = plt.subplots(figsize=(12, 12))
ax.scatter(10**bins[1:], hist)
#ax.set_yscale('log')
ax.set_xscale('log')
#ax.set_ylim(1, hist.max()*2)
ax.set_xlim((10**bins[1:].min())/2, 2*(10**bins[1:].max()))
# Out:
# (1.9666472022262172e-09, 0.012208768584903388)

# %%
#Calculate the switching time corresponding to each voltage drop
L = 1.
switching_times = L / np.array(voltage_drops)
switching_times.sort()

# The residence times are the gaps between switchings I apply a low end cuttoff to eliminate 0
# residence times from our
residence_times = np.ediff1d(switching_times)
residence_times = residence_times[residence_times > 1e-20]
residence_times.sort()
hist_switch, bins_switch = np.histogram(np.log10(switching_times), 300)
hist, bins = np.histogram(np.log10(residence_times[:-75]), 300)

pdf = hist / np.sum(hist)
cdf = np.cumsum(pdf)
ccdf = 1 - cdf

pdf_switch = hist_switch / np.sum(hist_switch)

fig, ax = plt.subplots(figsize = (15,12))
ax.scatter(10**bins[1:], ccdf)
ax.scatter(10**bins[1:], pdf, c='r')
ax.scatter(10**bins[1:], pdf_switch, c='g')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim((10**bins[1])/1.5 , 10**bins_switch[-1])
ax.set_ylim(1e-5, np.max(ccdf)*1.5)
# Out:
# (1e-05, 1.4999922317225378)

# %% [markdown]
# ### $\delta\neq 0$

# %%
#initialize the network
L = 64
p = 0.6
R_OFF = 1
delta = 0.1
R_ON = (1 - delta) * R_OFF
G_OFF = 1 / R_OFF
G_ON = 1 / R_ON
L_max = 1
random_lattice = G_OFF * gen_adj.cubic_2d_random((L,L), p)
v_external = np.empty(L*L) * np.nan
v_external[0:L] = 1
v_external[-L:] = 0
rnet = rnets.ResistorNetworkCC(random_lattice, v_external)

# %%
# initialize filament length matrix
filaments = random_lattice.copy() * (1e-10 / G_OFF)
#initialize voltage drop matrix
voltage_drops = random_lattice.copy()

residence_times = []
switching_indices = []

# %%
#Solve for the voltages
rnet.solve_voltages('spsolve')

# %%
# find the shortest switching time in the network
rows, cols = voltage_drops.nonzero()
shortest_switching_time = 1e20
shortest_indices = []
for i, j in zip(rows, cols):
    #matrices are symmetric. consider each memristor once
    if i < j:
        # If the filament has switched, ignore it
        if filaments[i, j] == L_max:
            voltage_drops[i, j] = 0
            voltage_drops[j, i] = 0
        else:
            #Calculate and set the voltage drop
            drop = np.abs(rnet.voltages[i] - rnet.voltages[j])
            if drop >= 1e-12:
                voltage_drops[i, j] = drop
                voltage_drops[j, i] = drop
                switching_time = (L_max - filaments[i, j]) / drop
            else:
                switching_time = 1e21
                voltage_drops[i, j] = 0
                voltage_drops[j, i] = 0
            #If it is shorter than what is stored, set it and drop the indices we have accumulated
            if switching_time < shortest_switching_time:
                shortest_switching_time = switching_time
                shortest_indices = [(i, j)]
            # if it matches the shortest so far, append the indices.
            elif switching_time == shortest_switching_time:
                shortest_indices.append((i, j))

# %%
#Update the network
filaments = filaments + shortest_switching_time * voltage_drops
for i, j in shortest_indices:
    filaments[i, j] = L_max
    filaments[j, i] = L_max
    rnet.G[i, j] = G_ON
    rnet.G[j, i] = G_ON
    voltage_drops[i, j] = 0
    voltage_drops[j, i] = 0

voltage_drops.eliminate_zeros()
    
residence_times.append(shortest_switching_time)
switching_indices.append(shortest_indices)

# %% [markdown]
# ### Putting it all together

# %%
# %%timeit

#initialize the network
L = 64
p = 0.6
R_OFF = 1
delta = 0.1
R_ON = (1 - delta) * R_OFF
G_OFF = 1 / R_OFF
G_ON = 1 / R_ON
L_max = 1
random_lattice = G_OFF * gen_adj.cubic_2d_random((L,L), p)
v_external = np.empty(L*L) * np.nan
v_external[0:L] = 1
v_external[-L:] = 0
rnet = rnets.ResistorNetworkCC(random_lattice, v_external)

# initialize filament length matrix
filaments = random_lattice.copy() * (1e-10 / G_OFF)
#initialize voltage drop matrix
voltage_drops = random_lattice.copy()

#initialize lists for saving results
residence_times = []
switching_indices = []

while voltage_drops.max() > 0:
    
    #Solve for the voltages
    rnet.solve_voltages('spsolve')
    
    # find the shortest switching time in the network
    rows, cols = voltage_drops.nonzero()
    shortest_switching_time = 1e20
    shortest_indices = []
    for i, j in zip(rows, cols):
        #matrices are symmetric. consider each memristor once
        if i < j:
            # If the filament has switched, ignore it
            if filaments[i, j] == L_max:
                voltage_drops[i, j] = 0
                voltage_drops[j, i] = 0
            else:
                #Calculate and set the voltage drop
                drop = np.abs(rnet.voltages[i] - rnet.voltages[j])
                if drop >= 1e-12:
                    voltage_drops[i, j] = drop
                    voltage_drops[j, i] = drop
                    switching_time = (L_max - filaments[i, j]) / drop
                else:
                    switching_time = 1e21
                    voltage_drops[i, j] = 0
                    voltage_drops[j, i] = 0
                #If it is shorter than what is stored, set it and drop the indices we have accumulated
                if switching_time < shortest_switching_time:
                    shortest_switching_time = switching_time
                    shortest_indices = [(i, j)]
                # if it matches the shortest so far, append the indices.
                elif switching_time == shortest_switching_time:
                    shortest_indices.append((i, j))

    #Update the network
    filaments = filaments + shortest_switching_time * voltage_drops
    for i, j in shortest_indices:
        filaments[i, j] = L_max
        filaments[j, i] = L_max
        rnet.G[i, j] = G_ON
        rnet.G[j, i] = G_ON
        voltage_drops[i, j] = 0
        voltage_drops[j, i] = 0
    
    #eliminate zero entries from storage
    voltage_drops.eliminate_zeros()
    
    residence_times.append(shortest_switching_time)
    switching_indices.append(shortest_indices)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-502dfd010149> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'timeit', u'', u"\n#initialize the network\nL = 64\np = 0.6\nR_OFF = 1\ndelta = 0.1\nR_ON = (1 - delta) * R_OFF\nG_OFF = 1 / R_OFF\nG_ON = 1 / R_ON\nL_max = 1\nrandom_lattice = G_OFF * gen_adj.cubic_2d_random((L,L), p)\nv_external = np.empty(L*L) * np.nan\nv_external[0:L] = 1\nv_external[-L:] = 0\nrnet = rnets.ResistorNetworkCC(random_lattice, v_external)\n\n# initialize filament length matrix\nfilaments = random_lattice.copy() * (1e-10 / G_OFF)\n#initialize voltage drop matrix\nvoltage_drops = random_lattice.copy()\n\n#initialize lists for saving results\nresidence_times = []\nswitching_indices = []\n\nwhile voltage_drops.max() > 0:\n    \n    #Solve for the voltages\n    rnet.solve_voltages('spsolve')\n    \n    # find the shortest switching time in the network\n    rows, cols = voltage_drops.nonzero()\n    shortest_switching_time = 1e20\n    shortest_indices = []\n    for i, j in zip(rows, cols):\n        #matrices are symmetric. consider each memristor once\n        if i < j:\n            # If the filament has switched, ignore it\n            if filaments[i, j] == L_max:\n                voltage_drops[i, j] = 0\n                voltage_drops[j, i] = 0\n            else:\n                #Calculate and set the voltage drop\n                drop = np.abs(rnet.voltages[i] - rnet.voltages[j])\n                if drop >= 1e-12:\n                    voltage_drops[i, j] = drop\n                    voltage_drops[j, i] = drop\n                    switching_time = (L_max - filaments[i, j]) / drop\n                else:\n                    switching_time = 1e21\n                    voltage_drops[i, j] = 0\n                    voltage_drops[j, i] = 0\n                #If it is shorter than what is stored, set it and drop the indices we have accumulated\n                if switching_time < shortest_switching_time:\n                    shortest_switching_time = switching_time\n                    shortest_indices = [(i, j)]\n                # if it matches the shortest so far, append the indices.\n                elif switching_time == shortest_switching_time:\n                    shortest_indices.append((i, j))\n\n    #Update the network\n    filaments = filaments + shortest_switching_time * voltage_drops\n    for i, j in shortest_indices:\n        filaments[i, j] = L_max\n        filaments[j, i] = L_max\n        rnet.G[i, j] = G_ON\n        rnet.G[j, i] = G_ON\n        voltage_drops[i, j] = 0\n        voltage_drops[j, i] = 0\n    \n    #eliminate zero entries from storage\n    voltage_drops.eliminate_zeros()\n    \n    residence_times.append(shortest_switching_time)\n    switching_indices.append(shortest_indices)")
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2160             magic_arg_s = self.var_expand(line, stack_depth)
#    2161             with self.builtin_trap:
# -> 2162                 result = fn(magic_arg_s, cell)
#    2163             return result
#    2164
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/magics/execution.pyc in timeit(self, line, cell)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/magics/execution.pyc in timeit(self, line, cell)
#    1014                     break
#    1015                 number *= 10
# -> 1016         all_runs = timer.repeat(repeat, number)
#    1017         best = min(all_runs) / number
#    1018         if not quiet :
#
# /usr/lib/python2.7/timeit.pyc in repeat(self, repeat, number)
#     221         r = []
#     222         for i in range(repeat):
# --> 223             t = self.timeit(number)
#     224             r.append(t)
#     225         return r
#
# /usr/lib/python2.7/timeit.pyc in timeit(self, number)
#     193         gc.disable()
#     194         try:
# --> 195             timing = self.inner(it, self.timer)
#     196         finally:
#     197             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/compressed.pyc in __setitem__(self, index, x)
#     597         # Set values
#     598         for ii, jj, xx in zip(i.ravel(), j.ravel(), x.ravel()):
# --> 599             self._set_one(ii, jj, xx)
#     600
#     601     def _get_single_element(self,row,col):
#
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/compressed.pyc in _set_one(self, row, col, val)
#     751                              % (row,col))
#     752
# --> 753         self.check_format(full_check=True)
#     754
#     755     ######################
#
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/compressed.pyc in check_format(self, full_check)
#     153                     raise ValueError("%s index values must be < %d" %
#     154                                         (minor_name,minor_dim))
# --> 155                 if self.indices.min() < 0:
#     156                     raise ValueError("%s index values must be >= 0" %
#     157                                         minor_name)
#
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.pyc in _amin(a, axis, out, keepdims)
#      19 def _amin(a, axis=None, out=None, keepdims=False):
#      20     return um.minimum.reduce(a, axis=axis,
# ---> 21                             out=out, keepdims=keepdims)
#      22
#      23 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
residence_times
# Out:
# [6.9068143755523597,
#  3.1574536626035621,
#  0.61122719911177859,
#  0.46569377229576137,
#  0.43381640331094951,
#  2.3876570626099229,
#  0.43431778488619727,
#  0.267890253346527,
#  0.38443964708447692,
#  0.24870798776933947,
#  1.3142172879066782,
#  0.27678153547846884,
#  0.35763386839193734,
#  0.065952844092969073,
#  1.3454595860019117e-14,
#  0.39950995180738869,
#  0.4606110428399578,
#  4.0351554721830502e-14,
#  0.090476522357462744,
#  0.51541517154370853,
#  0.20543315805631007,
#  0.58079734148588757,
#  3.0409880862651272e-14,
#  0.73733146648869874,
#  0.41541572601198096,
#  0.78001944448264782,
#  0.17483968351687135,
#  0.10400338467010181,
#  0.24826294918724123,
#  0.23955731826569757,
#  9.8873251130366504e-15,
#  0.02358137894834313,
#  0.40453337449083515,
#  1.5116169383453445e-14,
#  0.45761922715461939,
#  0.15844341421948782,
#  1.268001545842904e-13,
#  0.31801255689286884,
#  0.74592543526376309,
#  0.23487965425381477,
#  0.64063348550743271,
#  2.1891824124269084,
#  4.8738058543763682e-14,
#  0.5377760821094012,
#  0.11261426880381697,
#  0.0026854820772473529,
#  9.3559039249611254e-15,
#  0.41418579180444792,
#  1.8459456040440985,
#  1.0445634862652589e-13,
#  1.0782590825964e-13,
#  0.90636084202689138,
#  4.5112416708677622e-14,
#  0.3312058112102646,
#  1.4322867903115892,
#  1.9062217549307396,
#  5.8164090569120592e-14,
#  6.5919302645003471e-14,
#  0.05955471286920179,
#  1.5536871757149163e-13,
#  0.096795059573255182,
#  1.3687738289538471,
#  0.19802155360710005,
#  2.0344567902730676e-14,
#  0.45761270862258607,
#  0.34642341447997715,
#  0.25805133615814291,
#  4.6055118732717817e-14,
#  0.15044669452517498,
#  0.75871053745459582,
#  0.21632507413844038,
#  0.3261858433443019,
#  0.16776800525699651,
#  1.7466490025230484e-13,
#  1.8339814526492088e-13,
#  1.4868019021677825,
#  1.9386832308781181,
#  1.2929149401157747,
#  2.1518068644255752e-13,
#  2.1518068644255855e-13,
#  0.49250671939817442,
#  0.5878030393605701,
#  0.17348715504628431,
#  1.8575753210094943,
#  2.1050862740902994,
#  3.0383854153919749,
#  0.66632914047272729,
#  0.60291984740852766,
#  0.24985936277920204,
#  1.1977750455242639,
#  1.7714872069397645e-13,
#  0.15544394410484894,
#  0.33968294680232403,
#  0.85170841237889594,
#  0.79519937879908065,
#  2.1323733697708791,
#  2.8131615605083757,
#  2.6750024053318588,
#  0.95113364105865672,
#  0.40711416301784037,
#  4.6996707825035996e-13,
#  4.919967850433492e-13,
#  0.53661696691158423,
#  0.92063964152538225,
#  0.39181129564018108,
#  1.8616863231532441,
#  0.45879811571739898,
#  2.5632998591114822,
#  4.2358222420345637,
#  6.5919723789371977e-13,
#  2.366044654017629,
#  1.0066288959177903,
#  1.1523475755044361,
#  3.8773664617562456,
#  2.6762667007200709,
#  2.9975843883877884,
#  2.0249049649915993,
#  2.4194034556883914,
#  1.2539065762292376,
#  2.3649352641914092,
#  1.2092600361549806,
#  1.4427324161918622,
#  1.5475278691153356,
#  0.1006122986295654,
#  2.3441661864951451,
#  1.1756634376548421e-14,
#  3.9341740618152063,
#  1.4928617798397896,
#  1.0392702434398935,
#  2.245416941990672e-13,
#  1.1013256484597842,
#  1.7931533007185414,
#  7.1983892299590222,
#  4.0785216091276185e-14,
#  0.24379480379660107,
#  1.907099416722363e-13,
#  10.25667711595402,
#  5.8821084139072557,
#  6.9135738141756988,
#  9.7088788216189436e-14,
#  3.2362929405396481e-14,
#  3.0075935255429278,
#  1.321229972864712e-12,
#  4.2818475359787831,
#  5.1252525819398027,
#  2.2844179708166399,
#  9.6655960096178379,
#  7.1534715374940943,
#  2.2002747129891138,
#  4.9142649605047897,
#  0.24124799428330571,
#  0.97133822275124282,
#  7.7781243604762382,
#  0.56685125433475714,
#  1.7225328495334874e-13,
#  4.5601416921463711,
#  4.4075876098874224e-12,
#  45.93497754039047,
#  11.12417127236227,
#  2.6472869419903815,
#  0.093593399091624091,
#  6.2678164752306174,
#  6.5647736884377101,
#  2.4472746067456901e-11,
#  13.107999051326358,
#  14.80151480897757,
#  87.976716406349183,
#  27.9963846202381,
#  4.9406587305015188,
#  69.264658427892272,
#  87.055016574078564,
#  141.61111616009558,
#  404.54105015186025,
#  57.698954498407971,
#  3.8519995601892238e-11]

# %% [markdown]
# # Voltage Distributions

# %%
# %matplotlib inline

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import generate_adjacency_matrix as gen_adj
import resistor_networks as rnets
from __future__ import division

# %% [markdown]
# The [literature](http://journals.aps.org/prb/pdf/10.1103/PhysRevB.34.4656) reports that a random resistor network near the percolation threshold has log-normally distributed voltage drops and a number of interesting scaling properties.  This notebook will be aimed at confirming and reviewing these findings and understanding their consequences for memristor networks.

# %%
L = 256
p = 0.51
random_lattice = gen_adj.cubic_2d_random((L,L), p)
v_external = np.empty(L*L) * np.nan
v_external[0:L] = 1
v_external[-L:] = 0

rnet = rnets.ResistorNetworkCC(random_lattice, v_external)
rnet.solve_voltages('spsolve')

#fig, ax = plt.subplots(figsize=(10,10))
#rnet.display_grid(ax, (L,L), 'voltage')

# %%
def calculate_voltage_drops(G, voltages):
    rows, cols = G.nonzero()
    drops_list = []
    for i, j in zip(rows, cols):
        if i < j:
            drop = np.abs(voltages[i] - voltages[j])
            if drop > 1e-12:
                drops_list.append(drop)
    return drops_list

voltage_drops = calculate_voltage_drops(rnet.G, rnet.voltages)
len(voltage_drops)
# Out:
# 17060

# %%
len(voltage_drops)
hist, bins = np.histogram(np.log10(voltage_drops), 200)

fig, ax = plt.subplots(figsize=(12, 12))
ax.scatter(bins[1:], hist)
#ax.set_yscale('log')
#ax.set_xscale('log')
#ax.set_ylim(1, hist.max()*2)
#ax.set_xlim(bins[1:].min()/2, bins[1:].max())
# Out:
# array([-11.44964342, -11.40379183, -11.35794025, -11.31208866,
#        -11.26623708, -11.22038549, -11.17453391, -11.12868233,
#        -11.08283074, -11.03697916, -10.99112757, -10.94527599,
#        -10.89942441, -10.85357282, -10.80772124, -10.76186965,
#        -10.71601807, -10.67016648, -10.6243149 , -10.57846332,
#        -10.53261173, -10.48676015, -10.44090856, -10.39505698,
#        -10.34920539, -10.30335381, -10.25750223, -10.21165064,
#        -10.16579906, -10.11994747, -10.07409589, -10.02824431,
#         -9.98239272,  -9.93654114,  -9.89068955,  -9.84483797,
#         -9.79898638,  -9.7531348 ,  -9.70728322,  -9.66143163,
#         -9.61558005,  -9.56972846,  -9.52387688,  -9.4780253 ,
#         -9.43217371,  -9.38632213,  -9.34047054,  -9.29461896,
#         -9.24876737,  -9.20291579,  -9.15706421,  -9.11121262,
#         -9.06536104,  -9.01950945,  -8.97365787,  -8.92780629,
#         -8.8819547 ,  -8.83610312,  -8.79025153,  -8.74439995,
#         -8.69854836,  -8.65269678,  -8.6068452 ,  -8.56099361,
#         -8.51514203,  -8.46929044,  -8.42343886,  -8.37758728,
#         -8.33173569,  -8.28588411,  -8.24003252,  -8.19418094,
#         -8.14832935,  -8.10247777,  -8.05662619,  -8.0107746 ,
#         -7.96492302,  -7.91907143,  -7.87321985,  -7.82736827,
#         -7.78151668,  -7.7356651 ,  -7.68981351,  -7.64396193,
#         -7.59811034,  -7.55225876,  -7.50640718,  -7.46055559,
#         -7.41470401,  -7.36885242,  -7.32300084,  -7.27714926,
#         -7.23129767,  -7.18544609,  -7.1395945 ,  -7.09374292,
#         -7.04789133,  -7.00203975,  -6.95618817,  -6.91033658,
#         -6.864485  ,  -6.81863341,  -6.77278183,  -6.72693025,
#         -6.68107866,  -6.63522708,  -6.58937549,  -6.54352391,
#         -6.49767232,  -6.45182074,  -6.40596916,  -6.36011757,
#         -6.31426599,  -6.2684144 ,  -6.22256282,  -6.17671124,
#         -6.13085965,  -6.08500807,  -6.03915648,  -5.9933049 ,
#         -5.94745331,  -5.90160173,  -5.85575015,  -5.80989856,
#         -5.76404698,  -5.71819539,  -5.67234381,  -5.62649223,
#         -5.58064064,  -5.53478906,  -5.48893747,  -5.44308589,
#         -5.3972343 ,  -5.35138272,  -5.30553114,  -5.25967955,
#         -5.21382797,  -5.16797638,  -5.1221248 ,  -5.07627321,
#         -5.03042163,  -4.98457005,  -4.93871846,  -4.89286688,
#         -4.84701529,  -4.80116371,  -4.75531213,  -4.70946054,
#         -4.66360896,  -4.61775737,  -4.57190579,  -4.5260542 ,
#         -4.48020262,  -4.43435104,  -4.38849945,  -4.34264787,
#         -4.29679628,  -4.2509447 ,  -4.20509312,  -4.15924153,
#         -4.11338995,  -4.06753836,  -4.02168678,  -3.97583519,
#         -3.92998361,  -3.88413203,  -3.83828044,  -3.79242886,
#         -3.74657727,  -3.70072569,  -3.65487411,  -3.60902252,
#         -3.56317094,  -3.51731935,  -3.47146777,  -3.42561618,
#         -3.3797646 ,  -3.33391302,  -3.28806143,  -3.24220985,
#         -3.19635826,  -3.15050668,  -3.1046551 ,  -3.05880351,
#         -3.01295193,  -2.96710034,  -2.92124876,  -2.87539717,
#         -2.82954559,  -2.78369401,  -2.73784242,  -2.69199084,
#         -2.64613925,  -2.60028767,  -2.55443609,  -2.5085845 ,
#         -2.46273292,  -2.41688133,  -2.37102975,  -2.32517816,  -2.27932658])

# %%
L = 32
def exp_dist(x):
    return 0.5 * np.exp(-1 * (x - 1) / 1.5)

exp_lattice = gen_adj.locally_connected((L, L), exp_dist)
rnet = rnets.ResistorNetworkCC(exp_lattice, v_external)
rnet.solve_voltages('spsolve')
rows, cols = rnet.G.nonzero()
voltage_drops = []
for i, j in zip(rows, cols):
    if i < j:
        drop = np.abs(rnet.voltages[i] - rnet.voltages[j])
        if drop != 0:
            voltage_drops.append(drop)
            

hist, bins = np.histogram(np.log(voltage_drops), 1000)

fig, ax = plt.subplots(figsize=(12, 12))
ax.scatter(bins[1:], hist)
#ax.set_yscale('log')
#ax.set_xscale('log')
#ax.set_ylim(1, hist.max()*2)
#ax.set_xlim(bins[1:].min()/2, bins[1:].max())

# %%
fig, ax = plt.subplots()
rnet.display_grid(ax,(L, L), 'voltage')

# %%
filament_run = np.load('completed_runs/distributions/fil_cu51_GB_L64_V24_10x1000_2.npz')
final_voltages_1 = filament_run['final_voltages']
initial_voltages_1 = filament_run['initial_voltages']
initial_filaments_1 = filament_run['initial'].item()

# %%
initial_voltage_drops = calculate_voltage_drops(initial_filaments_1, initial_voltages_1)
final_voltage_drops = calculate_voltage_drops(initial_filaments_1, final_voltages_1)

# %%
# Out:
# []

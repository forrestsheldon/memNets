# %% [markdown]
# # Memristor Fuse Data

# %%
# %matplotlib inline

# %%
from __future__ import division
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
L128_p6_ON1_1 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON1.1run1.npz')
avalanches_L128_p6_ON1_1 = np.array([np.sum(i) for i in L128_p6_ON1_1['avalanches']])
steps_L128_p6_ON1_1 = np.array([len(i) for i in L128_p6_ON1_1['avalanches']])
cond_L128_p6_ON1_1 = L128_p6_ON1_1['conductivities']
voltage_L128_p6_ON1_1 = L128_p6_ON1_1['voltages']
L128_p6_ON1_5 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON1.5run1.npz')
avalanches_L128_p6_ON1_5 = np.array([np.sum(i) for i in L128_p6_ON1_5['avalanches']])
steps_L128_p6_ON1_5 = np.array([len(i) for i in L128_p6_ON1_5['avalanches']])
cond_L128_p6_ON1_5 = L128_p6_ON1_5['conductivities']
voltage_L128_p6_ON1_5 = L128_p6_ON1_5['voltages']
L128_p6_ON2 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON2run1.npz')
avalanches_L128_p6_ON2 = np.array([np.sum(i) for i in L128_p6_ON2['avalanches']])
steps_L128_p6_ON2 = np.array([len(i) for i in L128_p6_ON2['avalanches']])
cond_L128_p6_ON2 = L128_p6_ON2['conductivities']
voltage_L128_p6_ON2 = L128_p6_ON2['voltages']
L128_p6_ON4 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON4run1.npz')
avalanches_L128_p6_ON4 = np.array([np.sum(i) for i in L128_p6_ON4['avalanches']])
steps_L128_p6_ON4 = np.array([len(i) for i in L128_p6_ON4['avalanches']])
cond_L128_p6_ON4 = L128_p6_ON4['conductivities']
voltage_L128_p6_ON4 = L128_p6_ON4['voltages']
L128_p6_ON8 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON8run1.npz')
avalanches_L128_p6_ON8 = np.array([np.sum(i) for i in L128_p6_ON8['avalanches']])
steps_L128_p6_ON8 = np.array([len(i) for i in L128_p6_ON8['avalanches']])
cond_L128_p6_ON8 = L128_p6_ON8['conductivities']
voltage_L128_p6_ON8 = L128_p6_ON8['voltages']
L128_p6_ON16 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON16run1.npz')
avalanches_L128_p6_ON16 = np.array([np.sum(i) for i in L128_p6_ON16['avalanches']])
steps_L128_p6_ON16 = np.array([len(i) for i in L128_p6_ON16['avalanches']])
cond_L128_p6_ON16 = L128_p6_ON16['conductivities']
voltage_L128_p6_ON16 = L128_p6_ON16['voltages']
L128_p6_ON100 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON100run1.npz')
avalanches_L128_p6_ON100 = np.array([np.sum(i) for i in L128_p6_ON100['avalanches']])
steps_L128_p6_ON100 = np.array([len(i) for i in L128_p6_ON100['avalanches']])
cond_L128_p6_ON100 = L128_p6_ON100['conductivities']
voltage_L128_p6_ON100 = L128_p6_ON100['voltages']
L128_p6_ON1000 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON1000run1.npz')
avalanches_L128_p6_ON1000 = np.array([np.sum(i) for i in L128_p6_ON1000['avalanches']])
steps_L128_p6_ON1000 = np.array([len(i) for i in L128_p6_ON1000['avalanches']])
cond_L128_p6_ON1000 = L128_p6_ON1000['conductivities']
voltage_L128_p6_ON1000 = L128_p6_ON1000['voltages']

# %%
fig, ax = plt.subplots(8, 2, figsize=(15, 21))

ax[0,0].plot(avalanches_L128_p6_ON1_1)
ax[0,0].plot(np.cumsum(avalanches_L128_p6_ON1_1) * 100 / np.sum(avalanches_L128_p6_ON1_1))
ax[0,0].set_title('ON=1.1')
ax[0,0].set_ylim(0, 200)

ax[0,1].plot(steps_L128_p6_ON1_1)
ax[0,1].set_ylim(0, 30)

ax[1,0].plot(avalanches_L128_p6_ON1_5)
ax[1,0].plot(np.cumsum(avalanches_L128_p6_ON1_5) * 100 / np.sum(avalanches_L128_p6_ON1_5))
ax[1,0].set_title('ON=1.5')
ax[1,0].set_ylim(0, 200)

ax[1,1].plot(steps_L128_p6_ON1_5)
ax[1,1].set_ylim(0, 30)

ax[2,0].plot(avalanches_L128_p6_ON2)
ax[2,0].plot(np.cumsum(avalanches_L128_p6_ON2) * 100 / np.sum(avalanches_L128_p6_ON2))
ax[2,0].set_title('ON=2')
ax[2,0].set_ylim(0, 200)

ax[2,1].plot(steps_L128_p6_ON2)
ax[2,1].set_ylim(0, 30)

ax[3,0].plot(avalanches_L128_p6_ON4)
ax[3,0].plot(np.cumsum(avalanches_L128_p6_ON4) * 100 / np.sum(avalanches_L128_p6_ON4))
ax[3,0].set_title('ON=4')
ax[3,0].set_ylim(0, 200)

ax[3,1].plot(steps_L128_p6_ON4)
ax[3,1].set_ylim(0, 30)

ax[4,0].plot(avalanches_L128_p6_ON8)
ax[4,0].plot(np.cumsum(avalanches_L128_p6_ON8) * 100 / np.sum(avalanches_L128_p6_ON8))
ax[4,0].set_title('ON=8')
ax[4,0].set_ylim(0, 200)

ax[4,1].plot(steps_L128_p6_ON8)
ax[4,1].set_ylim(0, 30)

ax[5,0].plot(avalanches_L128_p6_ON16)
ax[5,0].plot(np.cumsum(avalanches_L128_p6_ON16) * 100 / np.sum(avalanches_L128_p6_ON16))
ax[5,0].set_title('ON=16')
ax[5,0].set_ylim(0, 200)

ax[5,1].plot(steps_L128_p6_ON16)
ax[5,1].set_ylim(0, 30)

ax[6,0].plot(avalanches_L128_p6_ON100)
ax[6,0].plot(np.cumsum(avalanches_L128_p6_ON100) * 100 / np.sum(avalanches_L128_p6_ON100))
ax[6,0].set_title('ON=100')
ax[6,0].set_ylim(0, 200)

ax[6,1].plot(steps_L128_p6_ON100)
ax[6,1].set_ylim(0, 30)

ax[7,0].plot(avalanches_L128_p6_ON1000)
ax[7,0].plot(np.cumsum(avalanches_L128_p6_ON1000) * 100 / np.sum(avalanches_L128_p6_ON1000))
ax[7,0].set_title('ON=1000')
ax[7,0].set_ylim(0, 200)

ax[7,1].plot(steps_L128_p6_ON1000)
ax[7,1].set_ylim(0, 30)


#for a in ax:
#    a.set_xlim(0, 10500)
#    a.set_ylim(0,600)

fig.tight_layout()

# %%
avalanches_L128_p6_ON1_1 = avalanches_L128_p6_ON1_1[500:]
steps_L128_p6_ON1_1 = steps_L128_p6_ON1_1[500:]
hist_L128_p6_ON1_1, bins_L128_p6_ON1_1 = np.histogram(avalanches_L128_p6_ON1_1[
                                         np.logical_and(avalanches_L128_p6_ON1_1>0, avalanches_L128_p6_ON1_1<100)], bins=30)
hist_steps_L128_p6_ON1_1, bins_steps_L128_p6_ON1_1 = np.histogram(steps_L128_p6_ON1_1[avalanches_L128_p6_ON1_1>0], bins=10)

avalanches_L128_p6_ON1_5 = avalanches_L128_p6_ON1_5[500:]
steps_L128_p6_ON1_5 = steps_L128_p6_ON1_5[500:]
hist_L128_p6_ON1_5, bins_L128_p6_ON1_5 = np.histogram(avalanches_L128_p6_ON1_5[
                                         np.logical_and(avalanches_L128_p6_ON1_5>0, avalanches_L128_p6_ON1_5<100)], bins=30)
hist_steps_L128_p6_ON1_5, bins_steps_L128_p6_ON1_5 = np.histogram(steps_L128_p6_ON1_5[avalanches_L128_p6_ON1_5>0], bins=12)

avalanches_L128_p6_ON2 = avalanches_L128_p6_ON2[500:]
steps_L128_p6_ON2 = steps_L128_p6_ON2[500:]
hist_L128_p6_ON2, bins_L128_p6_ON2 = np.histogram(avalanches_L128_p6_ON2[
                                         np.logical_and(avalanches_L128_p6_ON2>0, avalanches_L128_p6_ON2<100)], bins=30)
hist_steps_L128_p6_ON2, bins_steps_L128_p6_ON2 = np.histogram(steps_L128_p6_ON2[avalanches_L128_p6_ON2>0], bins=12)

avalanches_L128_p6_ON4 = avalanches_L128_p6_ON4[500:]
steps_L128_p6_ON4 = steps_L128_p6_ON4[500:]
hist_L128_p6_ON4, bins_L128_p6_ON4 = np.histogram(avalanches_L128_p6_ON4[
                                         np.logical_and(avalanches_L128_p6_ON4>0, avalanches_L128_p6_ON4<200)], bins=30)
hist_steps_L128_p6_ON4, bins_steps_L128_p6_ON4 = np.histogram(steps_L128_p6_ON4[avalanches_L128_p6_ON4>0], bins=20)

avalanches_L128_p6_ON8 = avalanches_L128_p6_ON8[500:]
steps_L128_p6_ON8 = steps_L128_p6_ON8[500:]
hist_L128_p6_ON8, bins_L128_p6_ON8 = np.histogram(avalanches_L128_p6_ON8[
                                         np.logical_and(avalanches_L128_p6_ON8>0, avalanches_L128_p6_ON8<200)], bins=30)
hist_steps_L128_p6_ON8, bins_steps_L128_p6_ON8 = np.histogram(steps_L128_p6_ON8[avalanches_L128_p6_ON8>0], bins=30)

avalanches_L128_p6_ON16 = avalanches_L128_p6_ON16[500:]
steps_L128_p6_ON16 = steps_L128_p6_ON16[500:]
hist_L128_p6_ON16, bins_L128_p6_ON16 = np.histogram(avalanches_L128_p6_ON16[
                                         np.logical_and(avalanches_L128_p6_ON16>0, avalanches_L128_p6_ON16<200)], bins=30)
hist_steps_L128_p6_ON16, bins_steps_L128_p6_ON16 = np.histogram(steps_L128_p6_ON16[avalanches_L128_p6_ON16>0], bins=30)

avalanches_L128_p6_ON100 = avalanches_L128_p6_ON100[500:]
steps_L128_p6_ON100 = steps_L128_p6_ON100[500:]
hist_L128_p6_ON100, bins_L128_p6_ON100 = np.histogram(avalanches_L128_p6_ON100[
                                         np.logical_and(avalanches_L128_p6_ON100>0, avalanches_L128_p6_ON100<200)], bins=30)
hist_steps_L128_p6_ON100, bins_steps_L128_p6_ON100 = np.histogram(steps_L128_p6_ON100[avalanches_L128_p6_ON100>0], bins=30)

avalanches_L128_p6_ON1000 = avalanches_L128_p6_ON1000[500:]
steps_L128_p6_ON1000 = steps_L128_p6_ON1000[500:]
hist_L128_p6_ON1000, bins_L128_p6_ON1000 = np.histogram(avalanches_L128_p6_ON1000[
                                         np.logical_and(avalanches_L128_p6_ON1000>0, avalanches_L128_p6_ON1000<200)], bins=30)
hist_steps_L128_p6_ON1000, bins_steps_L128_p6_ON1000 = np.histogram(steps_L128_p6_ON1000[avalanches_L128_p6_ON1000>0], bins=30)

fig, ax = plt.subplots(8, 2, figsize=(15, 28))

ax[0,0].scatter(bins_L128_p6_ON1_1[1:], hist_L128_p6_ON1_1, c='b')
ax[0,0].set_title('ON=1.1')
ax[0,0].set_xlim(1, 200)
ax[0,0].set_ylim(1, 9000)

ax[0,1].scatter(bins_steps_L128_p6_ON1_1[1:], hist_steps_L128_p6_ON1_1)
ax[0,1].set_xlim(2, 10)
ax[0,1].set_ylim(1, 6500)

ax[1,0].scatter(bins_L128_p6_ON1_5[1:], hist_L128_p6_ON1_5, c='b')
ax[1,0].set_title('ON=1.5')
ax[1,0].set_xlim(1, 200)
ax[1,0].set_ylim(1, 9000)

ax[1,1].scatter(bins_steps_L128_p6_ON1_5[1:], hist_steps_L128_p6_ON1_5)
ax[1,1].set_xlim(2, 60)
ax[1,1].set_ylim(1, 6500)

ax[2,0].scatter(bins_L128_p6_ON2[1:], hist_L128_p6_ON2, c='b')
ax[2,0].set_title('ON=2')
ax[2,0].set_xlim(1, 200)
ax[2,0].set_ylim(1, 9000)

ax[2,1].scatter(bins_steps_L128_p6_ON2[1:], hist_steps_L128_p6_ON2)
ax[2,1].set_xlim(2, 60)
ax[2,1].set_ylim(1, 6500)

ax[3,0].scatter(bins_L128_p6_ON4[1:], hist_L128_p6_ON4, c='b')
ax[3,0].set_title('ON=4')
ax[3,0].set_xlim(1, 200)
ax[3,0].set_ylim(1, 9000)

ax[3,1].scatter(bins_steps_L128_p6_ON4[1:], hist_steps_L128_p6_ON4)
ax[3,1].set_xlim(2, 60)
ax[3,1].set_ylim(1, 6500)

ax[4,0].scatter(bins_L128_p6_ON8[1:], hist_L128_p6_ON8, c='b')
ax[4,0].set_title('ON=8')
ax[4,0].set_xlim(1, 200)
ax[4,0].set_ylim(1, 9000)

ax[4,1].scatter(bins_steps_L128_p6_ON8[1:], hist_steps_L128_p6_ON8)
ax[4,1].set_xlim(2, 60)
ax[4,1].set_ylim(1, 6500)

ax[5,0].scatter(bins_L128_p6_ON16[1:], hist_L128_p6_ON16, c='b')
ax[5,0].set_title('ON=16')
ax[5,0].set_xlim(1, 200)
ax[5,0].set_ylim(1, 9000)

ax[5,1].scatter(bins_steps_L128_p6_ON16[1:], hist_steps_L128_p6_ON16)
ax[5,1].set_xlim(2, 60)
ax[5,1].set_ylim(1, 6500)

ax[6,0].scatter(bins_L128_p6_ON100[1:], hist_L128_p6_ON100, c='b')
ax[6,0].set_title('ON=100')
ax[6,0].set_xlim(1, 200)
ax[6,0].set_ylim(1, 9000)

ax[6,1].scatter(bins_steps_L128_p6_ON100[1:], hist_steps_L128_p6_ON100)
ax[6,1].set_xlim(2, 60)
ax[6,1].set_ylim(1, 6500)

ax[7,0].scatter(bins_L128_p6_ON1000[1:], hist_L128_p6_ON1000, c='b')
ax[7,0].set_title('ON=1000')
ax[7,0].set_xlim(1, 200)
ax[7,0].set_ylim(1, 9000)

ax[7,1].scatter(bins_steps_L128_p6_ON1000[1:], hist_steps_L128_p6_ON1000)
ax[7,1].set_xlim(2, 60)
ax[7,1].set_ylim(1, 6500)


for plot_row in ax:
    for a in plot_row:
        a.set_xscale('log')
        a.set_yscale('log')

    
fig.tight_layout()

# %% [markdown]
# ## Concentrations

# %% [markdown]
# ### ON=2

# %% [markdown]
# At low values of the ON/OFF ratio, the networks switch from low concentrations where the dynamics are dominated by a large avalanche at the end, to being dominated by a large avalanche at the beginning

# %%
L128_p5_ON2 = np.load('memristor_fuse_data/FuseNetwork_L128_p5_ON2run1.npz')
avalanches_L128_p5_ON2 = np.array([np.sum(i) for i in L128_p5_ON2['avalanches']])
steps_L128_p5_ON2 = np.array([len(i) for i in L128_p5_ON2['avalanches']])
cond_L128_p5_ON2 = L128_p5_ON2['conductivities']
voltage_L128_p5_ON2 = L128_p5_ON2['voltages']
L128_p6_ON2 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON2run1.npz')
avalanches_L128_p6_ON2 = np.array([np.sum(i) for i in L128_p6_ON2['avalanches']])
steps_L128_p6_ON2 = np.array([len(i) for i in L128_p6_ON2['avalanches']])
cond_L128_p6_ON2 = L128_p6_ON2['conductivities']
voltage_L128_p6_ON2 = L128_p6_ON2['voltages']
L128_p7_ON2 = np.load('memristor_fuse_data/FuseNetwork_L128_p7_ON2run1.npz')
avalanches_L128_p7_ON2 = np.array([np.sum(i) for i in L128_p7_ON2['avalanches']])
steps_L128_p7_ON2 = np.array([len(i) for i in L128_p7_ON2['avalanches']])
cond_L128_p7_ON2 = L128_p7_ON2['conductivities']
voltage_L128_p7_ON2 = L128_p7_ON2['voltages']
L128_p8_ON2 = np.load('memristor_fuse_data/FuseNetwork_L128_p8_ON2run1.npz')
avalanches_L128_p8_ON2 = np.array([np.sum(i) for i in L128_p8_ON2['avalanches']])
steps_L128_p8_ON2 = np.array([len(i) for i in L128_p8_ON2['avalanches']])
cond_L128_p8_ON2 = L128_p8_ON2['conductivities']
voltage_L128_p8_ON2 = L128_p8_ON2['voltages']
L128_p9_ON2 = np.load('memristor_fuse_data/FuseNetwork_L128_p9_ON2run1.npz')
avalanches_L128_p9_ON2 = np.array([np.sum(i) for i in L128_p9_ON2['avalanches']])
steps_L128_p9_ON2 = np.array([len(i) for i in L128_p9_ON2['avalanches']])
cond_L128_p9_ON2 = L128_p9_ON2['conductivities']
voltage_L128_p9_ON2 = L128_p9_ON2['voltages']

# %%
fig, ax = plt.subplots(5, 2, figsize=(15, 15))

ax[0,0].plot(avalanches_L128_p5_ON2)
ax[0,0].plot(np.cumsum(avalanches_L128_p5_ON2) * 100 / np.sum(avalanches_L128_p5_ON2))
ax[0,0].plot(voltage_L128_p5_ON2 / max(voltage_L128_p5_ON2) * max(avalanches_L128_p5_ON2))
ax[0,0].set_title('p=5')
#ax[0,0].set_ylim(0, 200)

ax[0,1].plot(steps_L128_p5_ON2)
ax[0,1].set_ylim(0, 30)

ax[1,0].plot(avalanches_L128_p6_ON2)
ax[1,0].plot(np.cumsum(avalanches_L128_p6_ON2) * 100 / np.sum(avalanches_L128_p6_ON2))
ax[1,0].plot(voltage_L128_p6_ON2 / max(voltage_L128_p6_ON2) * max(avalanches_L128_p6_ON2))
ax[1,0].set_title('p=6')
#ax[1,0].set_ylim(0, 200)

ax[1,1].plot(steps_L128_p6_ON2)
ax[1,1].set_ylim(0, 30)

ax[2,0].plot(avalanches_L128_p7_ON2)
ax[2,0].plot(np.cumsum(avalanches_L128_p7_ON2) * 100 / np.sum(avalanches_L128_p7_ON2))
ax[2,0].plot(voltage_L128_p7_ON2 / max(voltage_L128_p7_ON2) * max(avalanches_L128_p7_ON2))
ax[2,0].set_title('p=7')
#ax[2,0].set_ylim(0, 200)

ax[2,1].plot(steps_L128_p7_ON2)
ax[2,1].set_ylim(0, 30)

ax[3,0].plot(avalanches_L128_p8_ON2)
ax[3,0].plot(np.cumsum(avalanches_L128_p8_ON2) * 100 / np.sum(avalanches_L128_p8_ON2))
ax[3,0].plot(voltage_L128_p8_ON2 / max(voltage_L128_p8_ON2) * max(avalanches_L128_p8_ON2))
ax[3,0].set_title('p=8')
#ax[3,0].set_ylim(0, 200)

ax[3,1].plot(steps_L128_p8_ON2)
ax[3,1].set_ylim(0, 30)

ax[4,0].plot(avalanches_L128_p9_ON2)
ax[4,0].plot(np.cumsum(avalanches_L128_p9_ON2) * 100 / np.sum(avalanches_L128_p9_ON2))
ax[4,0].plot(voltage_L128_p9_ON2 / max(voltage_L128_p9_ON2) * max(avalanches_L128_p9_ON2))
ax[4,0].set_title('p=9')
#ax[4,0].set_ylim(0, 200)

ax[4,1].plot(steps_L128_p9_ON2)
ax[4,1].set_ylim(0, 30)
# Out:
# (0, 30)

# %%
avalanches_L128_p5_ON2 = avalanches_L128_p6_ON2[100:1100]
steps_L128_p5_ON2 = steps_L128_p5_ON2[100:1100]
hist_L128_p5_ON2, bins_L128_p5_ON2 = np.histogram(avalanches_L128_p5_ON2[
                                         np.logical_and(avalanches_L128_p5_ON2>0, avalanches_L128_p5_ON2<100)], bins=30)
hist_steps_L128_p5_ON2, bins_steps_L128_p5_ON2 = np.histogram(steps_L128_p5_ON2[avalanches_L128_p5_ON2>0], bins=10)

avalanches_L128_p6_ON2 = avalanches_L128_p6_ON2[2000:6500]
steps_L128_p6_ON2 = steps_L128_p6_ON2[2000:6500]
hist_L128_p6_ON2, bins_L128_p6_ON2 = np.histogram(avalanches_L128_p6_ON2[
                                         np.logical_and(avalanches_L128_p6_ON2>0, avalanches_L128_p6_ON2<100)], bins=30)
hist_steps_L128_p6_ON2, bins_steps_L128_p6_ON2 = np.histogram(steps_L128_p6_ON2[avalanches_L128_p6_ON2>0], bins=10)

avalanches_L128_p7_ON2 = avalanches_L128_p7_ON2[4000:10000]
steps_L128_p7_ON2 = steps_L128_p7_ON2[4000:10000]
hist_L128_p7_ON2, bins_L128_p7_ON2 = np.histogram(avalanches_L128_p7_ON2[
                                         np.logical_and(avalanches_L128_p7_ON2>0, avalanches_L128_p7_ON2<100)], bins=30)
hist_steps_L128_p7_ON2, bins_steps_L128_p7_ON2 = np.histogram(steps_L128_p7_ON2[avalanches_L128_p7_ON2>0], bins=10)

avalanches_L128_p8_ON2 = avalanches_L128_p8_ON2[4000:14000]
steps_L128_p8_ON2 = steps_L128_p8_ON2[4000:14000]
hist_L128_p8_ON2, bins_L128_p8_ON2 = np.histogram(avalanches_L128_p8_ON2[
                                         np.logical_and(avalanches_L128_p8_ON2>0, avalanches_L128_p8_ON2<100)], bins=30)
hist_steps_L128_p8_ON2, bins_steps_L128_p8_ON2 = np.histogram(steps_L128_p8_ON2[avalanches_L128_p8_ON2>0], bins=10)

avalanches_L128_p9_ON2 = avalanches_L128_p9_ON2[5000:15000]
steps_L128_p9_ON2 = steps_L128_p9_ON2[5000:15000]
hist_L128_p9_ON2, bins_L128_p9_ON2 = np.histogram(avalanches_L128_p9_ON2[
                                         np.logical_and(avalanches_L128_p9_ON2>0, avalanches_L128_p9_ON2<100)], bins=30)
hist_steps_L128_p9_ON2, bins_steps_L128_p9_ON2 = np.histogram(steps_L128_p9_ON2[avalanches_L128_p9_ON2>0], bins=10)

# %%
fig, ax = plt.subplots(5, 2, figsize=(15, 20))

ax[0,0].scatter(bins_L128_p5_ON2[1:], hist_L128_p5_ON2, c='b')
ax[0,0].set_title('p=5')
ax[0,0].set_xlim(1, 200)
ax[0,0].set_ylim(1, 9000)

ax[0,1].scatter(bins_steps_L128_p5_ON2[1:], hist_steps_L128_p5_ON2)
ax[0,1].set_xlim(2, 10)
ax[0,1].set_ylim(1, 6500)

ax[1,0].scatter(bins_L128_p6_ON2[1:], hist_L128_p6_ON2, c='b')
ax[1,0].set_title('p=6')
ax[1,0].set_xlim(1, 200)
ax[1,0].set_ylim(1, 9000)

ax[1,1].scatter(bins_steps_L128_p6_ON2[1:], hist_steps_L128_p6_ON2)
ax[1,1].set_xlim(2, 10)
ax[1,1].set_ylim(1, 6500)

ax[2,0].scatter(bins_L128_p7_ON2[1:], hist_L128_p7_ON2, c='b')
ax[2,0].set_title('p=7')
ax[2,0].set_xlim(1, 200)
ax[2,0].set_ylim(1, 9000)

ax[2,1].scatter(bins_steps_L128_p7_ON2[1:], hist_steps_L128_p7_ON2)
ax[2,1].set_xlim(2, 10)
ax[2,1].set_ylim(1, 6500)

ax[3,0].scatter(bins_L128_p8_ON2[1:], hist_L128_p8_ON2, c='b')
ax[3,0].set_title('p=8')
ax[3,0].set_xlim(1, 200)
ax[3,0].set_ylim(1, 9000)

ax[3,1].scatter(bins_steps_L128_p8_ON2[1:], hist_steps_L128_p8_ON2)
ax[3,1].set_xlim(2, 10)
ax[3,1].set_ylim(1, 6500)

ax[4,0].scatter(bins_L128_p9_ON2[1:], hist_L128_p9_ON2, c='b')
ax[4,0].set_title('p=9')
ax[4,0].set_xlim(1, 200)
ax[4,0].set_ylim(1, 9000)

ax[4,1].scatter(bins_steps_L128_p9_ON2[1:], hist_steps_L128_p9_ON2)
ax[4,1].set_xlim(2, 10)
ax[4,1].set_ylim(1, 6500)

for plot_row in ax:
    for a in plot_row:
        a.set_xscale('log')
        a.set_yscale('log')

    
fig.tight_layout()

# %% [markdown]
# ### ON=100

# %%
L128_p5_ON100 = np.load('memristor_fuse_data/FuseNetwork_L128_p5_ON100run1.npz')
avalanches_L128_p5_ON100 = np.array([np.sum(i) for i in L128_p5_ON100['avalanches']])
steps_L128_p5_ON100 = np.array([len(i) for i in L128_p5_ON100['avalanches']])
cond_L128_p5_ON100 = L128_p5_ON100['conductivities']
voltage_L128_p5_ON100 = L128_p5_ON100['voltages']
L128_p6_ON100 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON100run1.npz')
avalanches_L128_p6_ON100 = np.array([np.sum(i) for i in L128_p6_ON100['avalanches']])
steps_L128_p6_ON100 = np.array([len(i) for i in L128_p6_ON100['avalanches']])
cond_L128_p6_ON100 = L128_p6_ON100['conductivities']
voltage_L128_p6_ON100 = L128_p6_ON100['voltages']
L128_p7_ON100 = np.load('memristor_fuse_data/FuseNetwork_L128_p7_ON100run1.npz')
avalanches_L128_p7_ON100 = np.array([np.sum(i) for i in L128_p7_ON100['avalanches']])
steps_L128_p7_ON100 = np.array([len(i) for i in L128_p7_ON100['avalanches']])
cond_L128_p7_ON100 = L128_p7_ON100['conductivities']
voltage_L128_p7_ON100 = L128_p7_ON100['voltages']
L128_p8_ON100 = np.load('memristor_fuse_data/FuseNetwork_L128_p8_ON100run1.npz')
avalanches_L128_p8_ON100 = np.array([np.sum(i) for i in L128_p8_ON100['avalanches']])
steps_L128_p8_ON100 = np.array([len(i) for i in L128_p8_ON100['avalanches']])
cond_L128_p8_ON100 = L128_p8_ON100['conductivities']
voltage_L128_p8_ON100 = L128_p8_ON100['voltages']
L128_p9_ON100 = np.load('memristor_fuse_data/FuseNetwork_L128_p9_ON100run1.npz')
avalanches_L128_p9_ON100 = np.array([np.sum(i) for i in L128_p9_ON100['avalanches']])
steps_L128_p9_ON100 = np.array([len(i) for i in L128_p9_ON100['avalanches']])
cond_L128_p9_ON100 = L128_p9_ON100['conductivities']
voltage_L128_p9_ON100 = L128_p9_ON100['voltages']

# %%
fig, ax = plt.subplots(5, 2, figsize=(15, 15))

ax[0,0].plot(avalanches_L128_p5_ON100)
ax[0,0].plot(np.cumsum(avalanches_L128_p5_ON100) * 100 / np.sum(avalanches_L128_p5_ON100))
ax[0,0].set_title('p=5')
ax[0,0].set_ylim(0, 200)

ax[0,1].plot(steps_L128_p5_ON100)
#ax[0,1].set_ylim(0, 30)

ax[1,0].plot(avalanches_L128_p6_ON100)
ax[1,0].plot(np.cumsum(avalanches_L128_p6_ON100) * 100 / np.sum(avalanches_L128_p6_ON100))
ax[1,0].set_title('p=6')
ax[1,0].set_ylim(0, 200)

ax[1,1].plot(steps_L128_p6_ON100)
ax[1,1].set_ylim(0, 30)

ax[2,0].plot(avalanches_L128_p7_ON100)
ax[2,0].plot(np.cumsum(avalanches_L128_p7_ON100) * 100 / np.sum(avalanches_L128_p7_ON100))
ax[2,0].set_title('p=7')
ax[2,0].set_ylim(0, 200)

ax[2,1].plot(steps_L128_p7_ON100)
#ax[2,1].set_ylim(0, 30)

ax[3,0].plot(avalanches_L128_p8_ON100)
ax[3,0].plot(np.cumsum(avalanches_L128_p8_ON100) * 100 / np.sum(avalanches_L128_p8_ON100))
ax[3,0].set_title('p=8')
ax[3,0].set_ylim(0, 200)

ax[3,1].plot(steps_L128_p8_ON100)
ax[3,1].set_ylim(0, 30)

ax[4,0].plot(avalanches_L128_p9_ON100)
ax[4,0].plot(np.cumsum(avalanches_L128_p9_ON100) * 100 / np.sum(avalanches_L128_p9_ON100))
ax[4,0].set_title('p=9')
ax[4,0].set_ylim(0, 200)

ax[4,1].plot(steps_L128_p9_ON100)
ax[4,1].set_ylim(0, 30)
# Out:
# (0, 30)

# %%
avalanches_L128_p5_ON100 = avalanches_L128_p6_ON100[50:400]
steps_L128_p5_ON100 = steps_L128_p5_ON100[50:400]
hist_L128_p5_ON100, bins_L128_p5_ON100 = np.histogram(avalanches_L128_p5_ON100[
                                         np.logical_and(avalanches_L128_p5_ON100>0, avalanches_L128_p5_ON100<300)], bins=30)
hist_steps_L128_p5_ON100, bins_steps_L128_p5_ON100 = np.histogram(steps_L128_p5_ON100[avalanches_L128_p5_ON100>0], bins=10)

avalanches_L128_p6_ON100 = avalanches_L128_p6_ON100[500:1900]
steps_L128_p6_ON100 = steps_L128_p6_ON100[500:1900]
hist_L128_p6_ON100, bins_L128_p6_ON100 = np.histogram(avalanches_L128_p6_ON100[
                                         np.logical_and(avalanches_L128_p6_ON100>0, avalanches_L128_p6_ON100<100)], bins=30)
hist_steps_L128_p6_ON100, bins_steps_L128_p6_ON100 = np.histogram(steps_L128_p6_ON100[avalanches_L128_p6_ON100>0], bins=10)

avalanches_L128_p7_ON100 = avalanches_L128_p7_ON100[500:2000]
steps_L128_p7_ON100 = steps_L128_p7_ON100[500:2000]
hist_L128_p7_ON100, bins_L128_p7_ON100 = np.histogram(avalanches_L128_p7_ON100[
                                         np.logical_and(avalanches_L128_p7_ON100>0, avalanches_L128_p7_ON100<100)], bins=30)
hist_steps_L128_p7_ON100, bins_steps_L128_p7_ON100 = np.histogram(steps_L128_p7_ON100[avalanches_L128_p7_ON100>0], bins=10)

avalanches_L128_p8_ON100 = avalanches_L128_p8_ON100[500:2000]
steps_L128_p8_ON100 = steps_L128_p8_ON100[500:2000]
hist_L128_p8_ON100, bins_L128_p8_ON100 = np.histogram(avalanches_L128_p8_ON100[
                                         np.logical_and(avalanches_L128_p8_ON100>0, avalanches_L128_p8_ON100<100)], bins=30)
hist_steps_L128_p8_ON100, bins_steps_L128_p8_ON100 = np.histogram(steps_L128_p8_ON100[avalanches_L128_p8_ON100>0], bins=10)

avalanches_L128_p9_ON100 = avalanches_L128_p9_ON100[1000:6000]
steps_L128_p9_ON100 = steps_L128_p9_ON100[1000:6000]
hist_L128_p9_ON100, bins_L128_p9_ON100 = np.histogram(avalanches_L128_p9_ON100[
                                         np.logical_and(avalanches_L128_p9_ON100>0, avalanches_L128_p9_ON100<100)], bins=30)
hist_steps_L128_p9_ON100, bins_steps_L128_p9_ON100 = np.histogram(steps_L128_p9_ON100[avalanches_L128_p9_ON100>0], bins=10)

# %%
fig, ax = plt.subplots(5, 2, figsize=(15, 20))

ax[0,0].scatter(bins_L128_p5_ON100[1:], hist_L128_p5_ON100, c='b')
ax[0,0].set_title('p=5')
ax[0,0].set_xlim(1, 200)
ax[0,0].set_ylim(1, 9000)

ax[0,1].scatter(bins_steps_L128_p5_ON100[1:], hist_steps_L128_p5_ON100)
ax[0,1].set_xlim(2, 10)
ax[0,1].set_ylim(1, 6500)

ax[1,0].scatter(bins_L128_p6_ON100[1:], hist_L128_p6_ON100, c='b')
ax[1,0].set_title('p=6')
ax[1,0].set_xlim(1, 200)
ax[1,0].set_ylim(1, 9000)

ax[1,1].scatter(bins_steps_L128_p6_ON100[1:], hist_steps_L128_p6_ON100)
ax[1,1].set_xlim(2, 10)
ax[1,1].set_ylim(1, 6500)

ax[2,0].scatter(bins_L128_p7_ON100[1:], hist_L128_p7_ON100, c='b')
ax[2,0].set_title('p=7')
ax[2,0].set_xlim(1, 200)
ax[2,0].set_ylim(1, 9000)

ax[2,1].scatter(bins_steps_L128_p7_ON100[1:], hist_steps_L128_p7_ON100)
ax[2,1].set_xlim(2, 10)
ax[2,1].set_ylim(1, 6500)

ax[3,0].scatter(bins_L128_p8_ON100[1:], hist_L128_p8_ON100, c='b')
ax[3,0].set_title('p=8')
ax[3,0].set_xlim(1, 200)
ax[3,0].set_ylim(1, 9000)

ax[3,1].scatter(bins_steps_L128_p8_ON100[1:], hist_steps_L128_p8_ON100)
ax[3,1].set_xlim(2, 10)
ax[3,1].set_ylim(1, 6500)

ax[4,0].scatter(bins_L128_p9_ON100[1:], hist_L128_p9_ON100, c='b')
ax[4,0].set_title('p=9')
ax[4,0].set_xlim(1, 200)
ax[4,0].set_ylim(1, 9000)

ax[4,1].scatter(bins_steps_L128_p9_ON100[1:], hist_steps_L128_p9_ON100)
ax[4,1].set_xlim(2, 10)
ax[4,1].set_ylim(1, 6500)

for plot_row in ax:
    for a in plot_row:
        a.set_xscale('log')
        a.set_yscale('log')

    
fig.tight_layout()

# %% [markdown]
# ### L=256

# %%
L256_p6_ON100 = np.load('memristor_fuse_data/FuseNetwork_L256_p6_ON100run1.npz')
avalanches_p6_ON100 = np.array([np.sum(i) for i in L256_p6_ON100['avalanches']])

# %%
fig, ax = plt.subplots( figsize=(15, 3.5))
ax.plot(avalanches_p6_ON100)
ax.set_ylim(0, 1000)
# Out:
# (0, 1000)

# %%
hist_p6_ON100, bins_p6_ON100 = np.histogram(avalanches_p6_ON100[2000:5000][avalanches_p6_ON100[2000:5000]>0], bins=30)

fig, ax = plt.subplots(figsize=(8, 5))

ax.scatter(bins_p6_ON100[1:], hist_p6_ON100, c='b')


ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1.5, 200)
ax.set_ylim(1.5, 1000)
# Out:
# (1.5, 1000)

# %%
cond = L128_p6_ON1_1['conductivities'][500:]
Delta_cond = np.ediff1d(cond)
fig, ax = plt.subplots()
ax.plot(Delta_cond)
ax.set_ylim(0, 1e-4)
# Out:
# (0, 0.0001)

# %%
L128_p6_ON1_1.files
# Out:
# ['avalanches', 'conductivities', 'voltages', 'G']

# %% [markdown]
# # L=128 p=0.6 ON=100

# %%
L128_p6_ON100_1 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON100run1.npz')
avalanches_L128_p6_ON100_1 = np.array([np.sum(i) for i in L128_p6_ON100_1['avalanches']])
steps_L128_p6_ON100_1 = np.array([len(i) for i in L128_p6_ON100_1['avalanches']])
cond_L128_p6_ON100_1 = L128_p6_ON100_1['conductivities']
voltage_L128_p6_ON100_1 = L128_p6_ON100_1['voltages']
L128_p6_ON100_2 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON100run2.npz')
avalanches_L128_p6_ON100_2 = np.array([np.sum(i) for i in L128_p6_ON100_2['avalanches']])
steps_L128_p6_ON100_2 = np.array([len(i) for i in L128_p6_ON100_2['avalanches']])
cond_L128_p6_ON100_2 = L128_p6_ON100_2['conductivities']
voltage_L128_p6_ON100_2 = L128_p6_ON100_2['voltages']
L128_p6_ON100_3 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON100run3.npz')
avalanches_L128_p6_ON100_3 = np.array([np.sum(i) for i in L128_p6_ON100_3['avalanches']])
steps_L128_p6_ON100_3 = np.array([len(i) for i in L128_p6_ON100_3['avalanches']])
cond_L128_p6_ON100_3 = L128_p6_ON100_3['conductivities']
voltage_L128_p6_ON100_3 = L128_p6_ON100_3['voltages']
L128_p6_ON100_4 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON100run4.npz')
avalanches_L128_p6_ON100_4 = np.array([np.sum(i) for i in L128_p6_ON100_4['avalanches']])
steps_L128_p6_ON100_4 = np.array([len(i) for i in L128_p6_ON100_4['avalanches']])
cond_L128_p6_ON100_4 = L128_p6_ON100_4['conductivities']
voltage_L128_p6_ON100_4 = L128_p6_ON100_4['voltages']
L128_p6_ON100_5 = np.load('memristor_fuse_data/FuseNetwork_L128_p6_ON100run5.npz')
avalanches_L128_p6_ON100_5 = np.array([np.sum(i) for i in L128_p6_ON100_5['avalanches']])
steps_L128_p6_ON100_5 = np.array([len(i) for i in L128_p6_ON100_5['avalanches']])
cond_L128_p6_ON100_5 = L128_p6_ON100_5['conductivities']
voltage_L128_p6_ON100_5 = L128_p6_ON100_5['voltages']

# %%
fig, ax = plt.subplots(5, 2, figsize=(15, 13))

ax[0,0].plot(avalanches_L128_p6_ON100_1)
ax[0,0].plot(np.cumsum(avalanches_L128_p6_ON100_1) * 100 / np.sum(avalanches_L128_p6_ON100_1))
ax[0,0].set_title('run 1')
ax[0,0].set_ylim(0, 200)

ax[0,1].plot(steps_L128_p6_ON100_1)
ax[0,1].set_ylim(0, 30)

ax[1,0].plot(avalanches_L128_p6_ON100_1)
ax[1,0].plot(np.cumsum(avalanches_L128_p6_ON100_2) * 100 / np.sum(avalanches_L128_p6_ON100_2))
ax[1,0].set_title('run 2')
ax[1,0].set_ylim(0, 200)

ax[1,1].plot(steps_L128_p6_ON100_2)
ax[1,1].set_ylim(0, 30)

ax[2,0].plot(avalanches_L128_p6_ON100_3)
ax[2,0].plot(np.cumsum(avalanches_L128_p6_ON100_3) * 100 / np.sum(avalanches_L128_p6_ON100_3))
ax[2,0].set_title('run 3')
ax[2,0].set_ylim(0, 200)

ax[2,1].plot(steps_L128_p6_ON100_3)
ax[2,1].set_ylim(0, 30)

ax[3,0].plot(avalanches_L128_p6_ON100_4)
ax[3,0].plot(np.cumsum(avalanches_L128_p6_ON100_4) * 100 / np.sum(avalanches_L128_p6_ON100_4))
ax[3,0].set_title('run 4')
ax[3,0].set_ylim(0, 200)

ax[3,1].plot(steps_L128_p6_ON100_4)
ax[3,1].set_ylim(0, 30)

ax[4,0].plot(avalanches_L128_p6_ON100_5)
ax[4,0].plot(np.cumsum(avalanches_L128_p6_ON100_5) * 100 / np.sum(avalanches_L128_p6_ON100_5))
ax[4,0].set_title('run 5')
ax[4,0].set_ylim(0, 200)

ax[4,1].plot(steps_L128_p6_ON100_5)
ax[4,1].set_ylim(0, 30)

for a in ax:
    for b in a:
        b.set_xlim(0, 2000)

# %%
avalanches_L128_p6_ON100_1 = avalanches_L128_p6_ON100_1[500:-100]
steps_L128_p6_ON100_1 = steps_L128_p6_ON100_1[500:-100]
hist_L128_p6_ON100_1, bins_L128_p6_ON100_1 = np.histogram(avalanches_L128_p6_ON100_1[
                                         np.logical_and(avalanches_L128_p6_ON100_1>0, avalanches_L128_p6_ON100_1<200)], bins=30)
hist_steps_L128_p6_ON100_1, bins_steps_L128_p6_ON100_1 = np.histogram(steps_L128_p6_ON100_1[avalanches_L128_p6_ON100_1>0], bins=10)

avalanches_L128_p6_ON100_2 = avalanches_L128_p6_ON100_2[500:-100]
steps_L128_p6_ON100_2 = steps_L128_p6_ON100_2[500:-100]
hist_L128_p6_ON100_2, bins_L128_p6_ON100_2 = np.histogram(avalanches_L128_p6_ON100_2[
                                         np.logical_and(avalanches_L128_p6_ON100_2>0, avalanches_L128_p6_ON100_2<200)], bins=30)
hist_steps_L128_p6_ON100_2, bins_steps_L128_p6_ON100_2 = np.histogram(steps_L128_p6_ON100_2[avalanches_L128_p6_ON100_2>0], bins=10)

avalanches_L128_p6_ON100_3 = avalanches_L128_p6_ON100_3[500:-100]
steps_L128_p6_ON100_3 = steps_L128_p6_ON100_3[500:-100]
hist_L128_p6_ON100_3, bins_L128_p6_ON100_3 = np.histogram(avalanches_L128_p6_ON100_3[
                                         np.logical_and(avalanches_L128_p6_ON100_3>0, avalanches_L128_p6_ON100_3<200)], bins=30)
hist_steps_L128_p6_ON100_3, bins_steps_L128_p6_ON100_3 = np.histogram(steps_L128_p6_ON100_3[avalanches_L128_p6_ON100_3>0], bins=10)

avalanches_L128_p6_ON100_4 = avalanches_L128_p6_ON100_4[500:-100]
steps_L128_p6_ON100_4 = steps_L128_p6_ON100_4[500:-100]
hist_L128_p6_ON100_4, bins_L128_p6_ON100_4 = np.histogram(avalanches_L128_p6_ON100_4[
                                         np.logical_and(avalanches_L128_p6_ON100_4>0, avalanches_L128_p6_ON100_4<200)], bins=30)
hist_steps_L128_p6_ON100_4, bins_steps_L128_p6_ON100_4 = np.histogram(steps_L128_p6_ON100_4[avalanches_L128_p6_ON100_4>0], bins=10)

avalanches_L128_p6_ON100_5 = avalanches_L128_p6_ON100_5[500:-100]
steps_L128_p6_ON100_5 = steps_L128_p6_ON100_5[500:-100]
hist_L128_p6_ON100_5, bins_L128_p6_ON100_5 = np.histogram(avalanches_L128_p6_ON100_5[
                                         np.logical_and(avalanches_L128_p6_ON100_5>0, avalanches_L128_p6_ON100_5<200)], bins=30)
hist_steps_L128_p6_ON100_5, bins_steps_L128_p6_ON100_5 = np.histogram(steps_L128_p6_ON100_5[avalanches_L128_p6_ON100_5>0], bins=10)

# %%
fig, ax = plt.subplots(5, 2, figsize=(15, 15))

ax[0,0].scatter(bins_L128_p6_ON100_1[1:], hist_L128_p6_ON100_1, c='b')
ax[0,0].set_title('run 1')
ax[0,0].set_xlim(1, 200)
ax[0,0].set_ylim(1, 9000)

ax[0,1].scatter(bins_steps_L128_p6_ON100_1[1:], hist_steps_L128_p6_ON100_1)
ax[0,1].set_xlim(2, 10)
ax[0,1].set_ylim(1, 6500)

ax[1,0].scatter(bins_L128_p6_ON100_2[1:], hist_L128_p6_ON100_2, c='b')
ax[1,0].set_title('run 2')
ax[1,0].set_xlim(1, 200)
ax[1,0].set_ylim(1, 9000)

ax[1,1].scatter(bins_steps_L128_p6_ON100_2[1:], hist_steps_L128_p6_ON100_2)
ax[1,1].set_xlim(2, 10)
ax[1,1].set_ylim(1, 6500)

ax[2,0].scatter(bins_L128_p6_ON100_3[1:], hist_L128_p6_ON100_3, c='b')
ax[2,0].set_title('run 3')
ax[2,0].set_xlim(1, 200)
ax[2,0].set_ylim(1, 9000)

ax[2,1].scatter(bins_steps_L128_p6_ON100_3[1:], hist_steps_L128_p6_ON100_3)
ax[2,1].set_xlim(2, 10)
ax[2,1].set_ylim(1, 6500)

ax[3,0].scatter(bins_L128_p6_ON100_4[1:], hist_L128_p6_ON100_4, c='b')
ax[3,0].set_title('run 4')
ax[3,0].set_xlim(1, 200)
ax[3,0].set_ylim(1, 9000)

ax[3,1].scatter(bins_steps_L128_p6_ON100_4[1:], hist_steps_L128_p6_ON100_4)
ax[3,1].set_xlim(2, 10)
ax[3,1].set_ylim(1, 6500)

ax[4,0].scatter(bins_L128_p6_ON100_5[1:], hist_L128_p6_ON100_5, c='b')
ax[4,0].set_title('run 5')
ax[4,0].set_xlim(1, 200)
ax[4,0].set_ylim(1, 9000)

ax[4,1].scatter(bins_steps_L128_p6_ON100_5[1:], hist_steps_L128_p6_ON100_5)
ax[4,1].set_xlim(2, 10)
ax[4,1].set_ylim(1, 6500)

for a in ax:
    for b in a:
        b.set_xscale('log')
        b.set_yscale('log')

# %%
avalanches_L128_p6_ON100_all = np.concatenate((avalanches_L128_p6_ON100_1, avalanches_L128_p6_ON100_2, avalanches_L128_p6_ON100_3,
                                               avalanches_L128_p6_ON100_4, avalanches_L128_p6_ON100_5))
hist_L128_p6_ON100_all, bins_L128_p6_ON100_all = np.histogram(avalanches_L128_p6_ON100_all[avalanches_L128_p6_ON100_all>0], bins=30)

steps_L128_p6_ON100_all = np.concatenate((steps_L128_p6_ON100_1, steps_L128_p6_ON100_2, steps_L128_p6_ON100_3,
                                               steps_L128_p6_ON100_4, steps_L128_p6_ON100_5))
hist_steps_L128_p6_ON100_all, bins_steps_L128_p6_ON100_all = np.histogram(steps_L128_p6_ON100_all[
                                                             avalanches_L128_p6_ON100_all>0], bins=30)

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 3))

ax[0].scatter(bins_L128_p6_ON100_all[1:], hist_L128_p6_ON100_all)
ax[0].set_ylim(1, 9000)
ax[1].scatter(bins_steps_L128_p6_ON100_all[1:], hist_steps_L128_p6_ON100_all)
ax[1].set_ylim(1, 9000)

for a in ax:
    a.set_xscale('log')
    a.set_yscale('log')

# %%
avalanches=[]

for run in range(1,100):
    filename = "memristor_fuse_data/FuseNetwork_L256_p6_ON100run"+str(run)+".npz"
    current_run = np.load(filename)
    run_avalanches = np.array([np.sum(i) for i in current_run['avalanches']])
    avalanches = np.concatenate((avalanches, run_avalanches[750:1000]))

hist_256, bins_256 = np.histogram(avalanches[avalanches>0], bins=range(1,int(np.max(avalanches)+1)))

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ax.scatter(bins_256[1:], hist_256)
ax.set_xlim(1, 200)
ax.set_ylim(1, 100000)
ax.set_xscale('log')
ax.set_yscale('log')

# %%
avalanches=[]

for run in range(1,1000):
    filename = "memristor_fuse_data/FuseNetwork_L128_p6_ON100run"+str(run)+".npz"
    current_run = np.load(filename)
    run_avalanches = np.array([np.sum(i) for i in current_run['avalanches']])
    avalanches = np.concatenate((avalanches, run_avalanches[200:500]))

hist_128, bins_128 = np.histogram(avalanches[avalanches>0], bins=range(1,int(np.max(avalanches)+1)))

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ax.scatter(bins_128[1:], hist_128)
ax.set_xlim(1, 200)
ax.set_ylim(1, 100000)
ax.set_xscale('log')
ax.set_yscale('log')

# %%
avalanches_64=[]

for run in range(1,1000):
    filename = "memristor_fuse_data/FuseNetwork_L64_p6_ON100run"+str(run)+".npz"
    current_run = np.load(filename)
    run_avalanches = np.array([np.sum(i) for i in current_run['avalanches']])
    avalanches_64 = np.concatenate((avalanches_64, run_avalanches[100:200]))

hist_64, bins_64 = np.histogram(avalanches_64[avalanches_64>0], bins=range(1,int(np.max(avalanches_64)+1)))

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ax.scatter(bins_64[1:], hist_64)
ax.set_xlim(1, 200)
ax.set_ylim(1, 10000)
ax.set_xscale('log')
ax.set_yscale('log')

# %%
avalanches_32=[]

for run in np.concatenate((np.arange(1, 583), np.arange(584,716), np.arange(717, 789), np.arange(790,1000))):
    filename = "memristor_fuse_data/FuseNetwork_L32_p6_ON100run"+str(run)+".npz"
    current_run = np.load(filename)
    run_avalanches = np.array([np.sum(i) for i in current_run['avalanches']])
    avalanches_32 = np.concatenate((avalanches_32, run_avalanches[100:200]))

hist_32, bins_32 = np.histogram(avalanches_32[avalanches_32>0], bins=range(1,int(np.max(avalanches_32)+1)))

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ax.scatter(bins_32[1:], hist_32)
ax.set_xlim(1, 200)
ax.set_ylim(1, 10000)
ax.set_xscale('log')
ax.set_yscale('log')

# %%
fig, ax = plt.subplots(figsize=(10, 6))
pdf_256 = hist_256 / np.sum(hist_256)
pdf_128 = hist_128 / np.sum(hist_128)
pdf_64 = hist_64 / np.sum(hist_64)
pdf_32 = hist_32 / np.sum(hist_32)
ax.plot(bins_256[1:], pdf_256, c='k', alpha=0.9, lw=1.2)
ax.plot(bins_128[1:], pdf_128, c='r', alpha=0.7, lw=1.2)
ax.plot(bins_64[1:], pdf_64, c='g', alpha=0.7, lw=1.2)
ax.plot(bins_32[1:], pdf_32, c='darkorange', lw=1.2)
ax.plot(np.arange(1,10**3), [x**-(3/2) for x in np.arange(1, 10**3)], c='b', lw=2, alpha=0.7)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1, 10**3)
ax.set_ylim(1e-5, 1)

ax.set_title('Avalanche Size Distribution Near the Transition', fontsize=20)
ax.set_xlabel('Avalanche Size', fontsize=20)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.text(200, 0.001, r'$s^{-3/2}$', fontdict=dict(fontsize=24, color='b', alpha=0.8))
ax.text(230, 0.000047, r'$L=256$', fontdict=dict(fontsize=20, color='k', alpha=0.8))
ax.text(250, 0.000015, r'$L=128$', fontdict=dict(fontsize=20, color='r', alpha=0.8))
ax.text(20, 0.00005, r'$L=64$', fontdict=dict(fontsize=20, color='g', alpha=0.8))
ax.text(30, 0.000015, r'$L=32$', fontdict=dict(fontsize=20, color='darkorange'))

fig.savefig('Advancement_presentation/Avalanche_Lattice.png')

# %%
fig, ax = plt.subplots(figsize=(8.3, 5))
pdf_256 = hist_256 / np.sum(hist_256)
pdf_128 = hist_128 / np.sum(hist_128)
pdf_64 = hist_64 / np.sum(hist_64)
pdf_32 = hist_32 / np.sum(hist_32)
ax.plot(bins_256[1:], pdf_256, c='k', alpha=0.9, lw=1.2)
ax.plot(bins_128[1:], pdf_128, c='r', alpha=0.7, lw=1.2)
ax.plot(bins_64[1:], pdf_64, c='g', alpha=0.7, lw=1.2)
ax.plot(bins_32[1:], pdf_32, c='darkorange', lw=1.2)
ax.plot(np.arange(1,10**3), [x**-(3/2) for x in np.arange(1, 10**3)], c='b', lw=2, alpha=0.7)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1, 10**3)
ax.set_ylim(1e-5, 1)

#ax.set_title('Avalanche Size Distribution Near the Transition', fontsize=20)
ax.set_xlabel('Avalanche Size', fontsize=20)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.text(10, 0.05, r'$P (s)\sim s^{-3/2}$', fontdict=dict(fontsize=24, color='b', alpha=0.8))
ax.text(200, 0.0007, r'$L=256$', fontdict=dict(fontsize=24, color='k', alpha=0.8))
ax.text(340, 0.00025, r'$L=128$', fontdict=dict(fontsize=24, color='r', alpha=0.8))
ax.text(11, 0.0001, r'$L=64$', fontdict=dict(fontsize=24, color='g', alpha=0.8))
ax.text(15, 0.00004, r'$L=32$', fontdict=dict(fontsize=24, color='darkorange'))

fig.savefig('MF_paper/Avalanche_Size_Dist.png')

# %%
fig, ax = plt.subplots(figsize=(8.3, 5))
pdf_256 = hist_256 / np.sum(hist_256)
pdf_128 = hist_128 / np.sum(hist_128)
pdf_64 = hist_64 / np.sum(hist_64)
pdf_32 = hist_32 / np.sum(hist_32)
ax.plot(bins_256[1:], pdf_256, c='k', alpha=0.9, lw=1.2)
ax.plot(bins_128[1:], pdf_128, c='r', alpha=0.7, lw=1.2)
ax.plot(bins_64[1:], pdf_64, c='g', alpha=0.7, lw=1.2)
ax.plot(bins_32[1:], pdf_32, c='darkorange', lw=1.2)
ax.plot(np.arange(1,10**3), [x**-(3/2) for x in np.arange(1, 10**3)], c='b', lw=2, alpha=0.7)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1, 10**3)
ax.set_ylim(1e-5, 1)

#ax.set_title('Avalanche Size Distribution Near the Transition', fontsize=20)
ax.set_xlabel('Avalanche Size', fontsize=20)

#ax.spines['right'].set_visible(False)
#ax.spines['top'].set_visible(False)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.text(10, 0.05, r'$P (s)\sim s^{-3/2}$', fontdict=dict(fontsize=24, color='b', alpha=0.8))
ax.text(200, 0.0007, r'$L=256$', fontdict=dict(fontsize=22, color='k', alpha=0.8))
ax.text(320, 0.00025, r'$L=128$', fontdict=dict(fontsize=22, color='r', alpha=0.8))
ax.text(11, 0.0001, r'$L=64$', fontdict=dict(fontsize=22, color='g', alpha=0.8))
ax.text(15, 0.000035, r'$L=32$', fontdict=dict(fontsize=22, color='darkorange'))

fig.savefig('MF_paper/Avalanche_Size_Dist-2.png')

# %%
filename = "memristor_fuse_data/FuseNetwork_L256_p6_ON100run5.npz"
run = np.load(filename)
avalanches = np.array([np.sum(i) for i in run['avalanches']])

fig, ax = plt.subplots(figsize=(10,3))

ax.plot(avalanches)
ax.set_ylim(0,500)
# Out:
# (0, 500)

# %% [markdown]
# ### Conductances

# %%
filename = "memristor_fuse_data/FuseNetwork_L256_p6_ON100run10.npz"
runfiles = np.load(filename)
fig, ax = plt.subplots(figsize=(15, 4))
avalanches = np.array([np.sum(i) for i in runfiles['avalanches']])
ax.plot(runfiles['conductivities'][1:500])
ax.plot(avalanches[1:500]/ np.max(avalanches[1:500]) * np.max(runfiles['conductivities'][1:500]))
